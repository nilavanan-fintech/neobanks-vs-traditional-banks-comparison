# %% [markdown]
# # Week 3 — Score the product feature matrix
#
# Converts the qualitative Yes/Partial/No feature matrix into a numeric score so
# Week 4 can fold it into the composite comparison index.
#
# `Yes = 1.0`, `Partial = 0.5`, `No = 0.0`
#
# **Input:** `data/processed/feature_matrix_clean.csv`
#
# **Output:** `data/processed/feature_matrix_scored.csv`

# %%
from pathlib import Path

import pandas as pd

ROOT = Path.cwd().parent
PROCESSED = ROOT / "data" / "processed"

SCORE_MAP = {"Yes": 1.0, "Partial": 0.5, "No": 0.0}

# %%
df = pd.read_csv(PROCESSED / "feature_matrix_clean.csv")

for col in ["jupiter", "hdfc_bank"]:
    df[f"{col}_score"] = df[col].map(SCORE_MAP)

totals = pd.DataFrame({
    "feature": ["TOTAL / product-depth score"],
    "jupiter": [""],
    "hdfc_bank": [""],
    "notes_source": [""],
    "jupiter_score": [df["jupiter_score"].sum()],
    "hdfc_bank_score": [df["hdfc_bank_score"].sum()],
})
out = pd.concat([df, totals], ignore_index=True)

out.to_csv(PROCESSED / "feature_matrix_scored.csv", index=False)
print("-> data/processed/feature_matrix_scored.csv")
out[["feature", "jupiter_score", "hdfc_bank_score"]]
# Out:
# -> data/processed/feature_matrix_scored.csv
#                              feature  jupiter_score  hdfc_bank_score
# 0                    Savings Account            1.0              1.0
# 1                 Fixed Deposit (FD)            1.0              1.0
# 2                         Debit Card            1.0              1.0
# 3                        Credit Card            0.5              1.0
# 4                                UPI            1.0              1.0
# 5             Personal Loans/Lending            0.5              1.0
# 6            Investments (MF/Stocks)            0.5              1.0
# 7                          Insurance            0.5              0.5
# 8   Forex/International Transactions            0.5              1.0
# 9                   Rewards/Cashback            1.0              1.0
# 10       TOTAL / product-depth score            7.5              9.5
